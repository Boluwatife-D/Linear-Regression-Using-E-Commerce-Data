# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Exporting the csv file into a pandas dataframe
customers = pd.read_csv(r"C:\github\Linear-Regression-Using-E-Commerce-Data\Ecommerce Customers.csv")
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
# To view the top 5 rows in the dataset
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
customers.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
customers.isnull().sum().sort_values()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %% [markdown]
# ### EXPLORATORY ANALYSIS OF THE DATA

# %%
# To visualize the correlation between the time a customer spends on the website against their
# yealy spend on shopping with the company
sns.jointplot(x="Time on Website", y="Yearly Amount Spent", data=customers)

time_web_yearly_spent_corr = round(customers['Time on Website'].corr(customers['Yearly Amount Spent']), 3)
plt.figure(figsize=(10,10))
plt.scatter(x=customers['Time on Website'].values, y=customers['Yearly Amount Spent'].values,color='#0081C9',alpha=0.6, s=80)
plt.title(f'Time on Website Vs Yearly Amount Spent (Correlation {time_web_yearly_spent_corr})', fontsize=14)
plt.ylabel('Yearly Amount Spent', fontsize=12)
plt.xlabel('Time on Website', fontsize=12)
plt.show()

# %%
# Doing the same for the Time spent on the App using a jointplot in seaborn
sns.jointplot(x="Time on App", y="Yearly Amount Spent", data=customers)

time_app_yearly_spent_corr = round(customers['Time on App'].corr(customers['Yearly Amount Spent']), 3)
plt.figure(figsize=(10,10))
plt.scatter(x=customers['Time on App'].values, y=customers['Yearly Amount Spent'].values,color='#6C00FF',alpha=0.6, s=80)
plt.title(f'Time on App Vs Yearly Amount Spent (Correlation {time_app_yearly_spent_corr})', fontsize=14)
plt.ylabel('Yearly Amount Spent', fontsize=12)
plt.xlabel('Time on App', fontsize=12)
plt.show()

# %%
# To compare the Time spent on App and Length of Membership using jointplot to create a 2D hex bin plot

sns.set_theme(style="ticks")
a = customers['Time on App']
b = customers['Length of Membership']
sns.jointplot(x = a, y = b, kind="hex", color="#4CB391")

time_app_length_member_corr = round(customers['Time on App'].corr(customers['Length of Membership']), 3)
plt.figure(figsize=(10,10))
plt.scatter(x=customers['Time on App'].values, y=customers['Length of Membership'].values,color='#4CB391',alpha=0.6, s=80)
plt.title(f'Time on App Vs Length of Membership (Correlation {time_app_length_member_corr})', fontsize=14)
plt.ylabel('Length of Membership', fontsize=12)
plt.xlabel('Time on App', fontsize=12)
plt.show()

# %%
# To explore the different types of relationships across the data we use a pairplot
sns.pairplot(customers);

# %%
# From the previous plot we can observe that Length of membership appears to be more correlated the Yearly amount spent
# Therefore we can create a linear model of Length of membership against Yearly amount spent using a linear model plot 
sns.lmplot(x="Length of Membership", y="Yearly Amount Spent", height= 7, scatter_kws={'alpha': 0.6}, line_kws={'color':'red'}, data=customers)

graph_corr = round(customers['Length of Membership'].corr(customers['Yearly Amount Spent']), 3)
plt.figure(figsize=(10,10))
plt.scatter(x=customers['Length of Membership'].values, y=customers['Yearly Amount Spent'].values,color='#7B2869',alpha=0.6, s=80)
plt.title(f'Length of Membership Vs Yearly Amount Spent (Correlation {graph_corr })', fontsize=14)
plt.xlabel('Length of Membership', fontsize=12)
plt.ylabel('Yearly Amount Spent', fontsize=12)
plt.show()

# %%
# We can observe more clearly that the data points are within close limits which indicates a high positive correlation between Length of membership and yearly amount spent. i.e the longer a customers membership is, the more they spend

# %% [markdown]
# ### BUILDING THE LINEAR REGRESSION ALGORITHM

# %%
# Before we build the machine learning algorithm, we have to split the data to training and testing data first

# First we create two variables representing the dependent and independent variables
X = customers.drop(['Yearly Amount Spent', 'Email', 'Address', 'Avatar'], axis = 1)
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
Y = customers['Yearly Amount Spent']
Y
# Where X represents the independent variables and 
# Y represent the dependent variable
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620145
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, x_test, Y_train, y_test = train_test_split(X, Y, test_size = 0.30, random_state = 101)

# %% [markdown]
# ### TRAINING THE MODEL

# %%
# To import LinearRegression from sklearn.linear_model
from sklearn.linear_model import LinearRegression

# %%
# Creating an instance of a LinearRegression() model named lm.
lm = LinearRegression()

# %%
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# To see the coefficients of the model
coeff_df = pd.DataFrame(lm.coef_, X.columns, columns = ['Coefficient'])
coeff_df
# Out:
#                       Coefficient
# Avg. Session Length     25.981550
# Time on App             38.590159
# Time on Website          0.190405
# Length of Membership    61.279097

# %%
#To print out the intercept
print(lm.intercept_)
# Out:
# -1047.9327822502385

# %%
# Our fitted model is then given as 
# Yearly amount spent = -1047.9327822502385 + 25.981550(Avg. Session Length)  + 38.590159(Time on App) + 0.190405(Time on Website) + 61.279097(Length of Membership)
# Now that we have our fitted model, we then go ahead and use the test data on it to see the accuracy of our model
predictions = lm.predict(x_test)
predictions
# Out:
# array([456.44186104, 402.72005312, 409.2531539 , 591.4310343 ,
#        590.01437275, 548.82396607, 577.59737969, 715.44428115,
#        473.7893446 , 545.9211364 , 337.8580314 , 500.38506697,
#        552.93478041, 409.6038964 , 765.52590754, 545.83973731,
#        693.25969124, 507.32416226, 573.10533175, 573.2076631 ,
#        397.44989709, 555.0985107 , 458.19868141, 482.66899911,
#        559.2655959 , 413.00946082, 532.25727408, 377.65464817,
#        535.0209653 , 447.80070905, 595.54339577, 667.14347072,
#        511.96042791, 573.30433971, 505.02260887, 565.30254655,
#        460.38785393, 449.74727868, 422.87193429, 456.55615271,
#        598.10493696, 449.64517443, 615.34948995, 511.88078685,
#        504.37568058, 515.95249276, 568.64597718, 551.61444684,
#        356.5552241 , 464.9759817 , 481.66007708, 534.2220025 ,
#        256.28674001, 505.30810714, 520.01844434, 315.0298707 ,
#        501.98080155, 387.03842642, 472.97419543, 432.8704675 ,
# ...

# %%
# To see if our model is accurate we create a scatter plot of the predicted independent variables against the original ones
plt.scatter(y_test,predictions)

# %% [markdown]
# ### EVALUATING THE FITTED MODEL

# %%
# To import metrics that will be used to measure model accuracy
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 7.228148653430847
# MSE: 79.81305165097466
# RMSE: 8.933815066978646

# %% [markdown]
# ### RESIDUALS

# %%
# To get the residuals
residuals = predictions - y_test
residuals
# Out:
# 18     4.126186
# 361    1.686918
# 104   -0.816457
# 4     -7.975058
# 156    3.858503
#          ...
# 147   -1.431172
# 346   -3.977230
# 423   -3.521249
# 17     3.822028
# 259    0.080551
# Name: Yearly Amount Spent, Length: 150, dtype: float64

# %%
# Plotting the residuals should give us a normally distributed data
sns.distplot(residuals)
# Out:
# C:\Users\Boluwatife Deborah\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly Amount Spent', ylabel='Density'>

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# To answer the original question; From our analysis we can see that Time on app has a higher coefficient than Time on Website
#  i.e. people spend an average of 38.59 minutes on the App and spend as low as 0.19 seconds on the website meaning that
# the company should focus their resources on the App. It is also observed that customers with a longer length of membership tend to spend more on shopping. Therefore the company should focus on increasing customer experience for return customers while working on getting new customers
